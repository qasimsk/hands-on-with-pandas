# %%
import pandas as pd

# Reading the csv file
df = pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Reading the excel file
dfx = pd.read_excel("pokemon_data.xlsx")
dfx
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Reading the txt file
# For reading the text file we have to use a delimiter
dft = pd.read_csv("pokemon_data.txt", delimiter="\t")
dft
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# For reading n lines from starting we use df.head(n)
df.head(10) # Read 10 lines from the start of the dataframe
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
# For reading n lines from the end we use df.tail(n)
df.tail(10) # Read 10 lines from the end of the dataframe
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# ...

# %%
# For getting the headers of the dataframe
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Reading a specific column
df["Name"] # Getting the name column of dataframe
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# Reading a specific column and getting specific amount of rows from it
df["Name"][0:10] # Here getting from 0th to 10th
# Out:
# 0                    Bulbasaur
# 1                      Ivysaur
# 2                     Venusaur
# 3        VenusaurMega Venusaur
# 4                   Charmander
# 5                   Charmeleon
# 6                    Charizard
# 7    CharizardMega Charizard X
# 8    CharizardMega Charizard Y
# 9                     Squirtle
# Name: Name, dtype: object

# %%
# Getting multiple columns 
df[["Name", "Type 1", "Attack"]][0:10]
# Out:
#                         Name Type 1  Attack
# 0                  Bulbasaur  Grass      49
# 1                    Ivysaur  Grass      62
# 2                   Venusaur  Grass      82
# 3      VenusaurMega Venusaur  Grass     100
# 4                 Charmander   Fire      52
# 5                 Charmeleon   Fire      64
# 6                  Charizard   Fire      84
# 7  CharizardMega Charizard X   Fire     130
# 8  CharizardMega Charizard Y   Fire     104
# 9                   Squirtle  Water      48

# %%
# Getting a specific row with given index
df.iloc[4]
# Out:
# #                      4
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 4, dtype: object

# %%
# Getting specific number of rows from start and end index
df.iloc[4:8]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False

# %%
# Getting specific position using iloc
df.iloc[4, 1]
# Out:
# 'Charmander'

# %%
# Iterating each row
for index, row in df.iterrows():
  print(index, row["Name"], row["Type 1"])
# Out:
# 0 Bulbasaur Grass
# 1 Ivysaur Grass
# 2 Venusaur Grass
# 3 VenusaurMega Venusaur Grass
# 4 Charmander Fire
# 5 Charmeleon Fire
# 6 Charizard Fire
# 7 CharizardMega Charizard X Fire
# 8 CharizardMega Charizard Y Fire
# 9 Squirtle Water
# 10 Wartortle Water
# 11 Blastoise Water
# 12 BlastoiseMega Blastoise Water
# 13 Caterpie Bug
# 14 Metapod Bug
# 15 Butterfree Bug
# 16 Weedle Bug
# 17 Kakuna Bug
# 18 Beedrill Bug
# 19 BeedrillMega Beedrill Bug
# 20 Pidgey Normal
# 21 Pidgeotto Normal
# 22 Pidgeot Normal
# 23 PidgeotMega Pidgeot Normal
# 24 Rattata Normal
# 25 Raticate Normal
# 26 Spearow Normal
# 27 Fearow Normal
# 28 Ekans Poison
# 29 Arbok Poison
# 30 Pikachu Electric
# 31 Raichu Electric
# 32 Sandshrew Ground
# 33 Sandslash Ground
# 34 Nidoran (Female) Poison
# 35 Nidorina Poison
# 36 Nidoqueen Poison
# 37 Nidoran (Male) Poison
# 38 Nidorino Poison
# 39 Nidoking Poison
# 40 Clefairy Fairy
# 41 Clefable Fairy
# 42 Vulpix Fire
# 43 Ninetales Fire
# 44 Jigglypuff Normal
# ...

# %%
# Getting rows which contains specific data
df.loc[df["Type 1"] == "Fire"] # Here getting the rows where Type 1 of a pokemon is Fire
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...
