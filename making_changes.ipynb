# %%
import pandas as pd
df = pd.read_csv("pokemon_data.csv")

# Creating a new column
df["Total"] = df["HP"] + df["Attack"] + df["Defense"] + df["Sp. Atk"] + df["Sp. Def"] +  df["Speed"]
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# ...

# %%
# Dropping a specific column
df = df.drop(columns=["Total"])
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df = pd.read_csv("pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Adding a new column (better way)
# Getting the index of specific column in a rowb
hp_index = df.columns.get_loc("HP")
speed_index = df.columns.get_loc("Speed")
df["Total"] = df.iloc[:, hp_index:speed_index + 1].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
# Chaning the position of a column
type2_index = df.columns.get_loc("Type 2")
second_last_index = df.shape[1]
df = df[cols[0:type2_index] + [cols[-1]] + cols[type_2_index:second_last_index]]
df
# Out:
#        #                   Name   Type 1  Legendary  Type 2  Total  HP  \
# 0      1              Bulbasaur    Grass      False  Poison    318  45
# 1      2                Ivysaur    Grass      False  Poison    405  60
# 2      3               Venusaur    Grass      False  Poison    525  80
# 3      3  VenusaurMega Venusaur    Grass      False  Poison    625  80
# 4      4             Charmander     Fire      False     NaN    309  39
# ..   ...                    ...      ...        ...     ...    ...  ..
# 795  719                Diancie     Rock       True   Fairy    600  50
# 796  719    DiancieMega Diancie     Rock       True   Fairy    700  50
# 797  720    HoopaHoopa Confined  Psychic       True   Ghost    600  80
# 798  720     HoopaHoopa Unbound  Psychic       True    Dark    680  80
# 799  721              Volcanion     Fire       True   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Saving our new dataframe in csv
df.to_csv("modified_pokemon_data.csv")

# %%
# Saving our new dataframe in excel
df.to_excel("modified_pokemon_data.xlsx")

# %%
# Saving it without index
df.to_csv("modified_pokemon_data.csv", index=False)
df.to_excel("modified_pokemon_data.xlsx", index=False)
df.to_csv("modified_pokemon_data.txt", index=False, sep="\t")
