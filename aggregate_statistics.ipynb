# %%
import pandas as pd
df = pd.read_csv("modified_pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Legendary  Type 2  Total  HP  \
# 0      1              Bulbasaur    Grass      False  Poison    318  45
# 1      2                Ivysaur    Grass      False  Poison    405  60
# 2      3               Venusaur    Grass      False  Poison    525  80
# 3      3  VenusaurMega Venusaur    Grass      False  Poison    625  80
# 4      4             Charmander     Fire      False     NaN    309  39
# ..   ...                    ...      ...        ...     ...    ...  ..
# 795  719                Diancie     Rock       True   Fairy    600  50
# 796  719    DiancieMega Diancie     Rock       True   Fairy    700  50
# 797  720    HoopaHoopa Confined  Psychic       True   Ghost    600  80
# 798  720     HoopaHoopa Unbound  Psychic       True    Dark    680  80
# 799  721              Volcanion     Fire       True   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary.1
# ...

# %%
# Groupby a specific data
df.groupby(["Type 1"]).mean().sort_values("HP", ascending=False)
# Out:
#                    #  Legendary       Total         HP      Attack  \
# Type 1
# Dragon    474.375000   0.375000  550.531250  83.312500  112.125000
# Normal    319.173469   0.020408  401.683673  77.275510   73.469388
# Fairy     449.529412   0.058824  413.176471  74.117647   61.529412
# Ground    356.281250   0.125000  437.500000  73.781250   95.750000
# Water     303.089286   0.035714  430.455357  72.062500   74.151786
# Ice       423.541667   0.083333  433.458333  72.000000   72.750000
# Flying    677.750000   0.500000  485.000000  70.750000   78.750000
# Psychic   380.807018   0.245614  475.947368  70.631579   71.456140
# Fire      327.403846   0.096154  458.076923  69.903846   84.769231
# Fighting  363.851852   0.000000  416.444444  69.851852   96.777778
# Grass     344.871429   0.042857  421.142857  67.271429   73.214286
# Poison    251.785714   0.000000  399.142857  67.250000   74.678571
# Dark      461.354839   0.064516  445.741935  66.806452   88.387097
# ...

# %%
# Getting the count by Grouping by specific column values
df["count"] = 1
df.groupby(["Type 1", "Type 2"]).count()["count"]
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
